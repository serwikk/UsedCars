# %%
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt

# %%
vw = '../raw_data/vw.csv'

df_vw = pd.read_csv(vw)

# %%
df_vw
# Out:
#         model  year  price transmission  mileage fuelType  tax   mpg  \
# 0       T-Roc  2019  25000    Automatic    13904   Diesel  145  49.6
# 1       T-Roc  2019  26883    Automatic     4562   Diesel  145  49.6
# 2       T-Roc  2019  20000       Manual     7414   Diesel  145  50.4
# 3       T-Roc  2019  33492    Automatic     4825   Petrol  145  32.5
# 4       T-Roc  2019  22900    Semi-Auto     6500   Petrol  150  39.8
# ...       ...   ...    ...          ...      ...      ...  ...   ...
# 15152     Eos  2012   5990       Manual    74000   Diesel  125  58.9
# 15153     Fox  2008   1799       Manual    88102   Petrol  145  46.3
# 15154     Fox  2009   1590       Manual    70000   Petrol  200  42.0
# 15155     Fox  2006   1250       Manual    82704   Petrol  150  46.3
# 15156     Fox  2007   2295       Manual    74000   Petrol  145  46.3
#
#        engineSize
# 0             2.0
# 1             2.0
# 2             2.0
# 3             2.0
# 4             1.5
# ...           ...
# ...

# %% [markdown]
# ### Número de unidades por modelo (vw)

# %%
df_vw.groupby(df_vw['model']).size()
# Out:
# model
# Amarok              111
# Arteon              248
# Beetle               83
# CC                   95
# Caddy                 6
# Caddy Life            8
# Caddy Maxi            4
# Caddy Maxi Life      59
# California           15
# Caravelle           101
# Eos                   7
# Fox                   4
# Golf               4863
# Golf SV             268
# Jetta                32
# Passat              915
# Polo               3287
# Scirocco            242
# Sharan              260
# Shuttle              61
# T-Cross             300
# T-Roc               733
# Tiguan             1765
# Tiguan Allspace      91
# Touareg             363
# Touran              352
# Up                  884
# dtype: int64

# %%
df_vw.groupby(df_vw['model']).describe()
# Out:
#                    year                                                  \
#                   count         mean       std     min      25%     50%
# model
# Amarok            111.0  2017.819820  1.647026  2013.0  2017.00  2018.0
# Arteon            248.0  2018.822581  0.604281  2017.0  2019.00  2019.0
# Beetle             83.0  2013.722892  3.985686  2001.0  2014.00  2015.0
# CC                 95.0  2014.736842  1.354351  2011.0  2014.00  2015.0
# Caddy               6.0  2015.166667  1.722401  2012.0  2015.00  2015.5
# Caddy Life          8.0  2017.750000  2.314550  2013.0  2017.00  2018.0
# Caddy Maxi          4.0  2014.750000  2.061553  2012.0  2014.25  2015.0
# Caddy Maxi Life    59.0  2018.576271  1.234607  2014.0  2018.00  2019.0
# California         15.0  2019.000000  0.377964  2018.0  2019.00  2019.0
# Caravelle         101.0  2017.534653  3.288052  2005.0  2019.00  2019.0
# Eos                 7.0  2010.571429  3.359422  2006.0  2008.00  2011.0
# ...

# %%
vw_prices = df_vw.groupby(('model'))['price']

# %%
vw_prices.describe()
# Out:
#                   count          mean           std      min       25%  \
# model
# Amarok            111.0  27991.495495   7745.059969  12995.0  22990.00
# Arteon            248.0  26285.020161   3747.885319  18498.0  23612.00
# Beetle             83.0   9881.638554   3839.514605    899.0   7962.50
# CC                 95.0  10645.642105   2181.184691   6695.0   8999.50
# Caddy               6.0  12844.000000   1973.031171   9995.0  12121.75
# Caddy Life          8.0  17432.875000   3333.384871  11495.0  15746.00
# Caddy Maxi          4.0  11472.250000   2985.245425   9949.0   9983.50
# Caddy Maxi Life    59.0  19103.118644   2793.915823   9498.0  18350.00
# California         15.0  57593.866667   4136.410985  52991.0  54999.00
# Caravelle         101.0  39325.663366  11310.712622   7994.0  34999.00
# Eos                 7.0   6616.428571   3291.626642   2995.0   4345.00
# Fox                 4.0   1733.500000    437.392653   1250.0   1505.00
# ...

# %%
vw_prices.head()
# Out:
# 0        25000
# 1        26883
# 2        20000
# 3        33492
# 4        22900
#          ...
# 15150     8950
# 15153     1799
# 15154     1590
# 15155     1250
# 15156     2295
# Name: price, Length: 133, dtype: int64

# %%
plt.figure(figsize=(18, 6))  # (ancho, alto)
sn.boxplot(x='model', y='price', data=df_vw)
# Out:
# <Axes: xlabel='model', ylabel='price'>

# %%
model_counts = df_vw['model'].value_counts().reset_index()

# %%
model_counts
# Out:
#                model  count
# 0               Golf   4863
# 1               Polo   3287
# 2             Tiguan   1765
# 3             Passat    915
# 4                 Up    884
# 5              T-Roc    733
# 6            Touareg    363
# 7             Touran    352
# 8            T-Cross    300
# 9            Golf SV    268
# 10            Sharan    260
# 11            Arteon    248
# 12          Scirocco    242
# 13            Amarok    111
# 14         Caravelle    101
# 15                CC     95
# 16   Tiguan Allspace     91
# 17            Beetle     83
# 18           Shuttle     61
# 19   Caddy Maxi Life     59
# 20             Jetta     32
# 21        California     15
# 22        Caddy Life      8
# 23               Eos      7
# 24             Caddy      6
# 25        Caddy Maxi      4
# 26               Fox      4

# %%
plt.figure(figsize=(18, 6))  # (ancho, alto)
sn.lineplot(x='model', y='count', data=model_counts, marker='o')
# Out:
# <Axes: xlabel='model', ylabel='count'>

# %%
vw_golf = df_vw[df_vw['model'] == ' Golf']

# %%
vw_golf
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 733    Golf  2019  17000       Manual     8000   Diesel  145  57.7         1.6
# 734    Golf  2019  36000    Automatic     4000   Petrol  145  32.8         2.0
# 735    Golf  2015  19390    Automatic    20031   Petrol  200  40.4         2.0
# 736    Golf  2019  16290    Automatic    14821   Petrol  145  44.8         1.0
# 737    Golf  2017  16491    Automatic    20693   Petrol   20  60.1         1.4
# ...     ...   ...    ...          ...      ...      ...  ...   ...         ...
# 5591   Golf  2015  11750       Manual    79000   Diesel   20  67.3         2.0
# 5592   Golf  2016  11950    Automatic    41725   Petrol   30  53.3         1.4
# 5593   Golf  2017  12950    Automatic    44837   Diesel   20  67.3         2.0
# 5594   Golf  2014  11299       Manual    25495   Petrol   30  53.3         1.4
# 5595   Golf  2014   6251       Manual    97181   Diesel   20  68.9         2.0
#
# [4863 rows x 9 columns]

# %%
vw_golf.groupby(['fuelType']).count()
# Out:
#           model  year  price  transmission  mileage   tax   mpg  engineSize
# fuelType
# Diesel     2043  2043   2043          2043     2043  2043  2043        2043
# Hybrid       87    87     87            87       87    87    87          87
# Other        28    28     28            28       28    28    28          28
# Petrol     2705  2705   2705          2705     2705  2705  2705        2705

# %%
plt.figure(figsize=(18, 6))  # (ancho, alto)
sn.boxplot(x='year', y='price', data=vw_golf)
# Out:
# <Axes: xlabel='year', ylabel='price'>

# %%
vw_golf['mileage'] = round(vw_golf['mileage'] * 1.609, 0)
# Out:
# /tmp/ipykernel_39183/3815117721.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vw_golf['mileage'] = round(vw_golf['mileage'] * 1.609, 0)

# %%
vw_golf
# Out:
#       model  year  price transmission   mileage fuelType  tax   mpg  \
# 733    Golf  2019  17000       Manual   12872.0   Diesel  145  57.7
# 734    Golf  2019  36000    Automatic    6436.0   Petrol  145  32.8
# 735    Golf  2015  19390    Automatic   32230.0   Petrol  200  40.4
# 736    Golf  2019  16290    Automatic   23847.0   Petrol  145  44.8
# 737    Golf  2017  16491    Automatic   33295.0   Petrol   20  60.1
# ...     ...   ...    ...          ...       ...      ...  ...   ...
# 5591   Golf  2015  11750       Manual  127111.0   Diesel   20  67.3
# 5592   Golf  2016  11950    Automatic   67136.0   Petrol   30  53.3
# 5593   Golf  2017  12950    Automatic   72143.0   Diesel   20  67.3
# 5594   Golf  2014  11299       Manual   41021.0   Petrol   30  53.3
# 5595   Golf  2014   6251       Manual  156364.0   Diesel   20  68.9
#
#       engineSize
# 733          1.6
# 734          2.0
# 735          2.0
# 736          1.0
# 737          1.4
# ...          ...
# 5591         2.0
# ...

# %%
vw_golf_menos_5000eur_petrol = vw_golf[(vw_golf['price'] < 5000) & (vw_golf['fuelType'] == 'Petrol')]

# %%
vw_golf_menos_5000eur_petrol
# Out:
#       model  year  price transmission   mileage fuelType  tax   mpg  \
# 754    Golf  2009   4485       Manual   96540.0   Petrol  235  39.8
# 775    Golf  2009   4998       Manual  106194.0   Petrol  165  44.8
# 4830   Golf  2000   1999       Manual  129798.0   Petrol  245  35.8
# 4961   Golf  2006   2891       Manual  118368.0   Petrol  205  41.5
# 5083   Golf  2002   1275       Manual  188253.0   Petrol  280  35.8
# 5277   Golf  2004   1550       Manual  241350.0   Petrol  200  41.5
# 5306   Golf  2007   4295       Manual   68085.0   Petrol  200  40.4
# 5312   Golf  2005   2695       Manual  141592.0   Petrol  200  41.5
# 5313   Golf  2009   4795    Automatic  132815.0   Petrol  145  47.1
# 5463   Golf  2010   3980       Manual  114239.0   Petrol  150  43.5
# 5469   Golf  2009   3695       Manual  126855.0   Petrol  235  39.8
# 5473   Golf  2007   2999       Manual  151246.0   Petrol  205  40.4
# 5527   Golf  2008   2999       Manual  167336.0   Petrol  205  40.4
# ...
